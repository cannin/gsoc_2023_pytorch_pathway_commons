# %%
import pandas as pd

# %%
df = pd.read_csv("data_mutations.txt", sep="\t")

# %%
df.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0        OPN4         94233.0      .     GRCh37         10        88419681
# 1      GOLGA3          2802.0      .     GRCh37         12       133360652
# 2       KLRB1          3820.0      .     GRCh37         12         9760409
# 3       SALL2          6297.0      .     GRCh37         14        21991730
# 4       PLCB2          5330.0      .     GRCh37         15        40587141
#
#    End_Position Strand         Consequence Variant_Classification  ...  \
# 0      88419681      +    missense_variant      Missense_Mutation  ...
# 1     133360652      +      intron_variant                 Intron  ...
# 2       9760409      +    missense_variant      Missense_Mutation  ...
# 3      21991730      +    missense_variant      Missense_Mutation  ...
# 4      40587141      +  synonymous_variant                 Silent  ...
#
#   SYMBOL_SOURCE        TREMBL TSL        UNIPARC VARIANT_CLASS  \
# ...

# %%
df2 = pd.read_csv("data_mrna_seq_v2_rsem.txt", sep="\t")

# %%
df2.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id  TCGA-OR-A5J1-01  TCGA-OR-A5J2-01  \
# 0      NUDT18           79873          85.0144          165.884
# 1        SHC3           53358          97.5024           92.605
# 2  NCRNA00112           54089           0.0000            0.000
# 3      FAM49B           51571         671.9500          812.911
# 4       FMO6P          388714           0.0000            0.000
#
#    TCGA-OR-A5J3-01  TCGA-OR-A5J5-01  TCGA-OR-A5J6-01  TCGA-OR-A5J7-01  \
# 0         309.2880          178.931         124.0660         283.5940
# 1          10.0726           49.574           5.5886          50.9426
# 2           0.0000            0.000           0.0000           0.0000
# 3         482.2990          466.305        1074.6800         594.4650
# 4           0.0000            0.000           0.0000           0.0000
#
#    TCGA-OR-A5J8-01  TCGA-OR-A5J9-01  ...  TCGA-OR-A5LR-01  TCGA-OR-A5LS-01  \
# 0         283.4650         123.7530  ...         154.8120         176.1820
# ...
