# %% [markdown]
# <a href="https://colab.research.google.com/github/cannin/gsoc_2023_pytorch_pathway_commons/blob/main/Breast_cancer_preprocesing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# # Handling the cBIo Data

# %%
data_sample = pd.read_csv("/content/drive/MyDrive/gsoc data/Brca_tcga_2018/data_clinical_sample.txt", sep="\t")

# %%
data_sample.head()
# Out:
#                           #Patient Identifier            Sample Identifier  \
# 0  #Identifier to uniquely specify a patient.  A unique sample identifier.
# 1                                     #STRING                       STRING
# 2                                          #1                            1
# 3                                  PATIENT_ID                    SAMPLE_ID
# 4                                TCGA-3C-AAAU              TCGA-3C-AAAU-01
#
#    Oncotree Code    Cancer Type               Cancer Type Detailed  \
# 0  Oncotree Code    Cancer Type               Cancer Type Detailed
# 1         STRING         STRING                             STRING
# 2              1              1                                  1
# 3  ONCOTREE_CODE    CANCER_TYPE               CANCER_TYPE_DETAILED
# 4            ILC  Breast Cancer  Breast Invasive Lobular Carcinoma
#
#                        Tumor Type  \
# 0                      Tumor Type
# 1                          STRING
# 2                               1
# 3                      TUMOR_TYPE
# 4  Infiltrating Lobular Carcinoma
#
#                            Neoplasm Histologic Grade  \
# 0  Numeric value to express the degree of abnorma...
# 1                                             STRING
# 2                                                  1
# 3                                              GRADE
# 4                                                NaN
#
#     Tissue Prospective Collection Indicator  \
# 0  Tissue prospective collection indicator.
# 1                                    STRING
# 2                                         1
# 3   TISSUE_PROSPECTIVE_COLLECTION_INDICATOR
# 4                                        No
#
#     Tissue Retrospective Collection Indicator  Tissue Source Site Code  \
# 0  Tissue retrospective collection indicator.  Tissue Source Site Code
# 1                                      STRING                   STRING
# 2                                           1                        1
# 3   TISSUE_RETROSPECTIVE_COLLECTION_INDICATOR  TISSUE_SOURCE_SITE_CODE
# 4                                         Yes                       3C
#
#                          Tumor Disease Anatomic Site  Aneuploidy Score  \
# 0  Text term that describes the anatomic site of ...  Aneuploidy Score
# 1                                             STRING            NUMBER
# 2                                                  1                 1
# 3                                  TUMOR_TISSUE_SITE  ANEUPLOIDY_SCORE
# 4                                             Breast                19
#
#                                          Sample Type  \
# 0  The type of sample (i.e., normal, primary, met...
# 1                                             STRING
# 2                                                  9
# 3                                        SAMPLE_TYPE
# 4                                            Primary
#
#                                     MSI MANTIS Score  \
# 0  MSI Score reported by MANTIS. The suggested th...
# 1                                             NUMBER
# 2                                                  9
# 3                                   MSI_SCORE_MANTIS
# 4                                             0.3319
#
#                                      MSIsensor Score  Somatic Status  \
# 0  MSI Score reported by MSIsensor. The suggested...  Somatic Status
# 1                                             NUMBER          STRING
# 2                                                  9               1
# 3                                   MSI_SENSOR_SCORE  SOMATIC_STATUS
# 4                                               0.55         Matched
#
#    TMB (nonsynonymous)                                 Tissue Source Site
# 0  TMB (nonsynonymous)  A Tissue Source Site collects samples (tissue,...
# 1               NUMBER                                             STRING
# 2                    1                                                  1
# 3    TMB_NONSYNONYMOUS                                 TISSUE_SOURCE_SITE
# 4                  0.8                                Columbia University

# %%
ds1 = data_sample.drop([0,1,2,3])
ds1.head()
# Out:
#   #Patient Identifier Sample Identifier Oncotree Code    Cancer Type  \
# 4        TCGA-3C-AAAU   TCGA-3C-AAAU-01           ILC  Breast Cancer
# 5        TCGA-3C-AALI   TCGA-3C-AALI-01           IDC  Breast Cancer
# 6        TCGA-3C-AALJ   TCGA-3C-AALJ-01           IDC  Breast Cancer
# 7        TCGA-3C-AALK   TCGA-3C-AALK-01           IDC  Breast Cancer
# 8        TCGA-4H-AAAK   TCGA-4H-AAAK-01           ILC  Breast Cancer
#
#                 Cancer Type Detailed                      Tumor Type  \
# 4  Breast Invasive Lobular Carcinoma  Infiltrating Lobular Carcinoma
# 5   Breast Invasive Ductal Carcinoma   Infiltrating Ductal Carcinoma
# 6   Breast Invasive Ductal Carcinoma   Infiltrating Ductal Carcinoma
# 7   Breast Invasive Ductal Carcinoma   Infiltrating Ductal Carcinoma
# 8  Breast Invasive Lobular Carcinoma  Infiltrating Lobular Carcinoma
#
#   Neoplasm Histologic Grade Tissue Prospective Collection Indicator  \
# 4                       NaN                                      No
# 5                       NaN                                      No
# 6                       NaN                                      No
# 7                       NaN                                      No
# 8                       NaN                                     Yes
#
#   Tissue Retrospective Collection Indicator Tissue Source Site Code  \
# 4                                       Yes                      3C
# 5                                       Yes                      3C
# 6                                       Yes                      3C
# 7                                       Yes                      3C
# 8                                        No                      4H
#
#   Tumor Disease Anatomic Site Aneuploidy Score Sample Type MSI MANTIS Score  \
# 4                      Breast               19     Primary           0.3319
# 5                      Breast               22     Primary           0.3449
# 6                      Breast               13     Primary           0.3266
# 7                      Breast                4     Primary           0.3218
# 8                      Breast                7     Primary           0.3411
#
#   MSIsensor Score Somatic Status TMB (nonsynonymous)   Tissue Source Site
# 4            0.55        Matched                 0.8  Columbia University
# 5            0.74        Matched         15.26666667  Columbia University
# 6            0.31        Matched         0.933333333  Columbia University
# 7            0.03        Matched                 1.5  Columbia University
# 8            0.01        Matched                 0.7    Proteogenex, Inc.

# %%
ds1.shape
# Out:
# (1084, 18)

# %%
ds1.isnull().sum()
# Out:
# #Patient Identifier                             0
# Sample Identifier                               0
# Oncotree Code                                   0
# Cancer Type                                     0
# Cancer Type Detailed                            0
# Tumor Type                                      0
# Neoplasm Histologic Grade                    1084
# Tissue Prospective Collection Indicator         4
# Tissue Retrospective Collection Indicator       4
# Tissue Source Site Code                         0
# Tumor Disease Anatomic Site                     0
# Aneuploidy Score                               43
# Sample Type                                     0
# MSI MANTIS Score                               50
# MSIsensor Score                                 9
# Somatic Status                                  0
# TMB (nonsynonymous)                            18
# Tissue Source Site                              0
# dtype: int64

# %%
cleaned_ds = ds1.dropna(axis=1, how='all')
cleaned_ds.isnull().sum()
# Out:
# #Patient Identifier                           0
# Sample Identifier                             0
# Oncotree Code                                 0
# Cancer Type                                   0
# Cancer Type Detailed                          0
# Tumor Type                                    0
# Tissue Prospective Collection Indicator       4
# Tissue Retrospective Collection Indicator     4
# Tissue Source Site Code                       0
# Tumor Disease Anatomic Site                   0
# Aneuploidy Score                             43
# Sample Type                                   0
# MSI MANTIS Score                             50
# MSIsensor Score                               9
# Somatic Status                                0
# TMB (nonsynonymous)                          18
# Tissue Source Site                            0
# dtype: int64

# %%
cleaned_ds = cleaned_ds.fillna(method='ffill')

# %%
cleaned_ds = cleaned_ds.drop(columns='Cancer Type')

# %%
data_patient = pd.read_csv("/content/drive/MyDrive/gsoc data/Brca_tcga_2018/data_clinical_patient.txt", sep="\t")

# %%
dcp = data_patient.drop([0,1,2,3])
dcp.head()
# Out:
#   #Patient Identifier    Subtype TCGA PanCanAtlas Cancer Type Acronym  \
# 4        TCGA-3C-AAAU  BRCA_LumA                                 BRCA
# 5        TCGA-3C-AALI  BRCA_Her2                                 BRCA
# 6        TCGA-3C-AALJ  BRCA_LumB                                 BRCA
# 7        TCGA-3C-AALK  BRCA_LumA                                 BRCA
# 8        TCGA-4H-AAAK  BRCA_LumA                                 BRCA
#
#                        Other Patient ID Diagnosis Age     Sex  \
# 4  6E7D5EC6-A469-467C-B748-237353C23416            55  Female
# 5  55262FCB-1B01-4480-B322-36570430C917            50  Female
# 6  427D0648-3F77-4FFC-B52C-89855426D647            62  Female
# 7  C31900A4-5DCD-4022-97AC-638E86E889E4            52  Female
# 8  6623FC5E-00BE-4476-967A-CBD55F676EA6            50  Female
#
#   Neoplasm Disease Stage American Joint Committee on Cancer Code  \
# 4                                            STAGE X
# 5                                          STAGE IIB
# 6                                          STAGE IIB
# 7                                           STAGE IA
# 8                                         STAGE IIIA
#
#   American Joint Committee on Cancer Publication Version Type  \
# 4                                                6TH
# 5                                                6TH
# 6                                                7TH
# 7                                                7TH
# 8                                                7TH
#
#   Last Communication Contact from Initial Pathologic Diagnosis Date  \
# 4                                               4047
# 5                                               4005
# 6                                               1474
# 7                                               1448
# 8                                                348
#
#   Birth from Initial Pathologic Diagnosis Date  ... Patient Weight  \
# 4                                       -20211  ...            NaN
# 5                                       -18538  ...            NaN
# 6                                       -22848  ...            NaN
# 7                                       -19074  ...            NaN
# 8                                       -18371  ...            NaN
#
#   In PanCan Pathway Analysis Overall Survival Status  \
# 4                        Yes                0:LIVING
# 5                        Yes                0:LIVING
# 6                        Yes                0:LIVING
# 7                        Yes                0:LIVING
# 8                        Yes                0:LIVING
#
#   Overall Survival (Months) Disease-specific Survival status  \
# 4               133.0505967       0:ALIVE OR DEAD TUMOR FREE
# 5               131.6697899       0:ALIVE OR DEAD TUMOR FREE
# 6               48.45974291       0:ALIVE OR DEAD TUMOR FREE
# 7               47.60495775       0:ALIVE OR DEAD TUMOR FREE
# 8               11.44097051       0:ALIVE OR DEAD TUMOR FREE
#
#   Months of disease-specific survival    Disease Free Status  \
# 4                         133.0505967  1:Recurred/Progressed
# 5                         131.6697899          0:DiseaseFree
# 6                         48.45974291          0:DiseaseFree
# 7                         47.60495775                    NaN
# 8                         11.44097051          0:DiseaseFree
#
#   Disease Free (Months) Progression Free Status  \
# 4           59.44044449           1:PROGRESSION
# 5           131.6697899              0:CENSORED
# 6           48.45974291              0:CENSORED
# 7                   NaN              0:CENSORED
# 8           11.44097051              0:CENSORED
#
#   Progress Free Survival (Months)
# 4                     59.44044449
# 5                     131.6697899
# 6                     48.45974291
# 7                     47.60495775
# 8                     11.44097051
#
# [5 rows x 37 columns]

# %%
dcp.isnull().sum()
# Out:
# #Patient Identifier                                                                               0
# Subtype                                                                                         103
# TCGA PanCanAtlas Cancer Type Acronym                                                              0
# Other Patient ID                                                                                  0
# Diagnosis Age                                                                                     0
# Sex                                                                                               0
# Neoplasm Disease Stage American Joint Committee on Cancer Code                                    5
# American Joint Committee on Cancer Publication Version Type                                     140
# Last Communication Contact from Initial Pathologic Diagnosis Date                               104
# Birth from Initial Pathologic Diagnosis Date                                                     15
# Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value                            0
# Ethnicity Category                                                                              169
# Form completion date                                                                              0
# Neoadjuvant Therapy Type Administered Prior To Resection Text                                     1
# ICD-10 Classification                                                                             0
# International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code       0
# International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code            0
# Informed consent verified                                                                         0
# New Neoplasm Event Post Initial Therapy Indicator                                               199
# American Joint Committee on Cancer Metastasis Stage Code                                          0
# Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code                         0
# American Joint Committee on Cancer Tumor Stage Code                                               0
# Person Neoplasm Cancer Status                                                                   123
# Primary Lymph Node Presentation Assessment                                                      364
# Prior Diagnosis                                                                                   1
# Race Category                                                                                    90
# Radiation Therapy                                                                               101
# Patient Weight                                                                                 1084
# In PanCan Pathway Analysis                                                                        0
# Overall Survival Status                                                                           0
# Overall Survival (Months)                                                                         0
# Disease-specific Survival status                                                                 20
# Months of disease-specific survival                                                               2
# Disease Free Status                                                                             142
# Disease Free (Months)                                                                           143
# Progression Free Status                                                                           1
# Progress Free Survival (Months)                                                                   2
# dtype: int64

# %%
dcp = dcp.dropna(how='any', axis=1)

# %%
merged_df = pd.merge(cleaned_ds, dcp, on='#Patient Identifier')

# %%
merged_df.head()
# Out:
#   #Patient Identifier Sample Identifier Oncotree Code  \
# 0        TCGA-3C-AAAU   TCGA-3C-AAAU-01           ILC
# 1        TCGA-3C-AALI   TCGA-3C-AALI-01           IDC
# 2        TCGA-3C-AALJ   TCGA-3C-AALJ-01           IDC
# 3        TCGA-3C-AALK   TCGA-3C-AALK-01           IDC
# 4        TCGA-4H-AAAK   TCGA-4H-AAAK-01           ILC
#
#                 Cancer Type Detailed                      Tumor Type  \
# 0  Breast Invasive Lobular Carcinoma  Infiltrating Lobular Carcinoma
# 1   Breast Invasive Ductal Carcinoma   Infiltrating Ductal Carcinoma
# 2   Breast Invasive Ductal Carcinoma   Infiltrating Ductal Carcinoma
# 3   Breast Invasive Ductal Carcinoma   Infiltrating Ductal Carcinoma
# 4  Breast Invasive Lobular Carcinoma  Infiltrating Lobular Carcinoma
#
#   Tissue Prospective Collection Indicator  \
# 0                                      No
# 1                                      No
# 2                                      No
# 3                                      No
# 4                                     Yes
#
#   Tissue Retrospective Collection Indicator Tissue Source Site Code  \
# 0                                       Yes                      3C
# 1                                       Yes                      3C
# 2                                       Yes                      3C
# 3                                       Yes                      3C
# 4                                        No                      4H
#
#   Tumor Disease Anatomic Site Aneuploidy Score  ... ICD-10 Classification  \
# 0                      Breast               19  ...                 C50.9
# 1                      Breast               22  ...                 C50.9
# 2                      Breast               13  ...                 C50.9
# 3                      Breast                4  ...                 C50.9
# 4                      Breast                7  ...                 C50.9
#
#   International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code  \
# 0                                             8520/3
# 1                                             8500/3
# 2                                             8500/3
# 3                                             8500/3
# 4                                             8520/3
#
#   International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code  \
# 0                                              C50.9
# 1                                              C50.9
# 2                                              C50.9
# 3                                              C50.9
# 4                                              C50.9
#
#   Informed consent verified  \
# 0                       Yes
# 1                       Yes
# 2                       Yes
# 3                       Yes
# 4                       Yes
#
#   American Joint Committee on Cancer Metastasis Stage Code  \
# 0                                                 MX
# 1                                                 M0
# 2                                                 M0
# 3                                                 M0
# 4                                                 M0
#
#   Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code  \
# 0                                                 NX
# 1                                                N1A
# 2                                                N1A
# 3                                            N0 (I+)
# 4                                                N2A
#
#   American Joint Committee on Cancer Tumor Stage Code  \
# 0                                                 TX
# 1                                                 T2
# 2                                                 T2
# 3                                                T1C
# 4                                                 T2
#
#   In PanCan Pathway Analysis Overall Survival Status Overall Survival (Months)
# 0                        Yes                0:LIVING               133.0505967
# 1                        Yes                0:LIVING               131.6697899
# 2                        Yes                0:LIVING               48.45974291
# 3                        Yes                0:LIVING               47.60495775
# 4                        Yes                0:LIVING               11.44097051
#
# [5 rows x 32 columns]

# %%
merged_df.columns
# Out:
# Index(['#Patient Identifier', 'Sample Identifier', 'Oncotree Code',
#        'Cancer Type Detailed', 'Tumor Type',
#        'Tissue Prospective Collection Indicator',
#        'Tissue Retrospective Collection Indicator', 'Tissue Source Site Code',
#        'Tumor Disease Anatomic Site', 'Aneuploidy Score', 'Sample Type',
#        'MSI MANTIS Score', 'MSIsensor Score', 'Somatic Status',
#        'TMB (nonsynonymous)', 'Tissue Source Site',
#        'TCGA PanCanAtlas Cancer Type Acronym', 'Other Patient ID',
#        'Diagnosis Age', 'Sex',
#        'Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value',
#        'Form completion date', 'ICD-10 Classification',
#        'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code',
#        'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code',
#        'Informed consent verified',
#        'American Joint Committee on Cancer Metastasis Stage Code',
#        'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code',
#        'American Joint Committee on Cancer Tumor Stage Code',
#        'In PanCan Pathway Analysis', 'Overall Survival Status',
#        'Overall Survival (Months)'],
#       dtype='object')

# %%
# Assuming your DataFrame is named 'df'
columns_to_keep = ['#Patient Identifier', 'Sample Identifier', 'Overall Survival (Months)']
used_df = merged_df[columns_to_keep]

# %%
used_df.head()
# Out:
#   #Patient Identifier Sample Identifier Overall Survival (Months)
# 0        TCGA-3C-AAAU   TCGA-3C-AAAU-01               133.0505967
# 1        TCGA-3C-AALI   TCGA-3C-AALI-01               131.6697899
# 2        TCGA-3C-AALJ   TCGA-3C-AALJ-01               48.45974291
# 3        TCGA-3C-AALK   TCGA-3C-AALK-01               47.60495775
# 4        TCGA-4H-AAAK   TCGA-4H-AAAK-01               11.44097051

# %%
used_df.shape
# Out:
# (1084, 3)

# %%
df = pd.read_csv("/content/drive/MyDrive/gsoc data/Brca_tcga_2018/data_mrna_seq_v2_rsem.txt", sep="\t")

# %%
patients = df.copy()
patients.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id  TCGA-3C-AAAU-01  TCGA-3C-AALI-01  \
# 0         NaN       100130426           0.0000           0.0000
# 1         NaN       100133144          16.3644           9.2659
# 2    UBE2Q2P2       100134869          12.9316          17.3790
# 3     HMGB1P1           10357          52.1503          69.7553
# 4         NaN           10431         408.0760         563.8930
#
#    TCGA-3C-AALJ-01  TCGA-3C-AALK-01  TCGA-4H-AAAK-01  TCGA-5L-AAT0-01  \
# 0           0.9066           0.0000           0.0000           0.0000
# 1          11.6228          12.0894           6.8468           3.9889
# 2           9.2294          11.0799          14.4298          13.6090
# 3         154.2970         143.8640          84.2128         114.2570
# 4        1360.8300         865.5360         766.3830         807.7430
#
#    TCGA-5T-A9QA-01  TCGA-A1-A0SB-01  ...  TCGA-UL-AAZ6-01  TCGA-UU-A93S-01  \
# 0           0.0000           0.0000  ...           0.0000           0.0000
# 1           1.4644          15.3396  ...           0.3992           4.3126
# 2           8.9958          14.3935  ...          14.3720          10.8828
# 3         107.5630         116.3870  ...         135.6240         136.1290
# 4        1420.5000         657.2810  ...        1570.1400        2886.4000
#
#    TCGA-V7-A7HQ-01  TCGA-W8-A86G-01  TCGA-WT-AB41-01  TCGA-WT-AB44-01  \
# 0           0.0000           0.0000           0.0000           0.0000
# 1           0.0000           5.5624           0.0000           0.0000
# 2           3.0792          14.3711           6.3091           3.2580
# 3          29.9974         128.3150          53.6278          42.2643
# 4        1721.8800         697.6740        1245.2700        1877.4200
#
#    TCGA-XX-A899-01  TCGA-XX-A89A-01  TCGA-Z7-A8R5-01  TCGA-Z7-A8R6-01
# 0           0.0000           0.0000           0.0000           0.0000
# 1          14.3858          22.3240           2.2638           6.8865
# 2          21.4409          27.2744           7.2933          24.7795
# 3         137.7760          64.1427          85.0461         167.5510
# 4         652.7560         722.7210        1140.2800        1003.5700
#
# [5 rows x 1084 columns]

# %%
patients = patients.drop('Entrez_Gene_Id', axis=1)

# %%
patients.shape
# Out:
# (20531, 1083)

# %%
patients.isnull().sum()
# Out:
# Hugo_Symbol        13
# TCGA-3C-AAAU-01     0
# TCGA-3C-AALI-01     0
# TCGA-3C-AALJ-01     0
# TCGA-3C-AALK-01     0
#                    ..
# TCGA-WT-AB44-01     0
# TCGA-XX-A899-01     0
# TCGA-XX-A89A-01     0
# TCGA-Z7-A8R5-01     0
# TCGA-Z7-A8R6-01     0
# Length: 1083, dtype: int64

# %%
patients = patients.dropna()

# %%
identifiers = patients['Hugo_Symbol'].unique()
print(len(identifiers))
# Out:
# 20511

# %%
# Check for duplicate 'Hugo_Symbol' values
duplicates = patients['Hugo_Symbol'].duplicated(keep='last')

# Drop rows with duplicate 'Hugo_Symbol' or same symbol as the previous row
new_df = patients[~duplicates]

# Verify the updated DataFrame shape
print(new_df.shape)
# Out:
# (20511, 1083)

# %%
new_df.shape
# Out:
# (20511, 1083)

# %%
new_df_transposed = new_df.set_index('Hugo_Symbol').transpose()
new_df_transposed.head()
# Out:
# Hugo_Symbol      UBE2Q2P2   HMGB1P1  RNU12-2P   SSX9P     EZHIP  EFCAB8  \
# TCGA-3C-AAAU-01   12.9316   52.1503    0.0000  0.0000    1.7233  0.3447
# TCGA-3C-AALI-01   17.3790   69.7553    1.0875  0.5438  144.1000  4.8940
# TCGA-3C-AALJ-01    9.2294  154.2970    0.0000  0.0000    0.0000  2.7199
# TCGA-3C-AALK-01   11.0799  143.8640    0.4137  0.0000    0.0000  2.0687
# TCGA-4H-AAAK-01   14.4298   84.2128    0.4255  0.0000    0.4255  2.9787
#
# Hugo_Symbol      SRP14P1  TRIM75P  SPATA31B1P  REXO1L6P  ...    ZWILCH  \
# TCGA-3C-AAAU-01   4.1359   0.6893         0.0       0.0  ...   415.824
# TCGA-3C-AALI-01   1.6313   0.5438         0.0       0.0  ...  1161.330
# TCGA-3C-AALJ-01   2.7199   0.0000         0.0       0.0  ...   305.422
# TCGA-3C-AALK-01   4.5511   0.0000         0.0       0.0  ...   394.506
# TCGA-4H-AAAK-01   2.9787   0.0000         0.0       0.0  ...   405.711
#
# Hugo_Symbol         ZWINT      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B  \
# TCGA-3C-AAAU-01   931.957  129.5920  1007.780  1658.500  258.4940  1208.370
# TCGA-3C-AALI-01   965.198   59.8151   448.613  1343.120  198.4770   603.589
# TCGA-3C-AALJ-01  2531.280   35.3581   533.998   768.812  331.8220   532.185
# TCGA-3C-AALK-01   668.597   55.0269   437.733   863.881  175.4240   607.365
# TCGA-4H-AAAK-01   674.468   48.9362   424.255  1049.790   14.0426   775.745
#
# Hugo_Symbol          ZYX     ZZEF1      ZZZ3
# TCGA-3C-AAAU-01  3507.25  1894.930  1180.460
# TCGA-3C-AALI-01  5504.62  1318.650   406.743
# TCGA-3C-AALJ-01  5458.75   942.883   509.519
# TCGA-3C-AALK-01  5691.35   781.134   700.869
# TCGA-4H-AAAK-01  4041.70   831.915   881.702
#
# [5 rows x 20511 columns]

# %%
# Merge the datasets based on the patient identifiers
patient_df = pd.merge(used_df, new_df_transposed, left_on='Sample Identifier', right_index=True)

# %%
patient_df.shape
# Out:
# (1082, 20514)

# %%
patient_df.head()
# Out:
#   #Patient Identifier Sample Identifier Overall Survival (Months)  UBE2Q2P2  \
# 0        TCGA-3C-AAAU   TCGA-3C-AAAU-01               133.0505967   12.9316
# 1        TCGA-3C-AALI   TCGA-3C-AALI-01               131.6697899   17.3790
# 2        TCGA-3C-AALJ   TCGA-3C-AALJ-01               48.45974291    9.2294
# 3        TCGA-3C-AALK   TCGA-3C-AALK-01               47.60495775   11.0799
# 4        TCGA-4H-AAAK   TCGA-4H-AAAK-01               11.44097051   14.4298
#
#     HMGB1P1  RNU12-2P   SSX9P     EZHIP  EFCAB8  SRP14P1  ...    ZWILCH  \
# 0   52.1503    0.0000  0.0000    1.7233  0.3447   4.1359  ...   415.824
# 1   69.7553    1.0875  0.5438  144.1000  4.8940   1.6313  ...  1161.330
# 2  154.2970    0.0000  0.0000    0.0000  2.7199   2.7199  ...   305.422
# 3  143.8640    0.4137  0.0000    0.0000  2.0687   4.5511  ...   394.506
# 4   84.2128    0.4255  0.0000    0.4255  2.9787   2.9787  ...   405.711
#
#       ZWINT      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B      ZYX  \
# 0   931.957  129.5920  1007.780  1658.500  258.4940  1208.370  3507.25
# 1   965.198   59.8151   448.613  1343.120  198.4770   603.589  5504.62
# 2  2531.280   35.3581   533.998   768.812  331.8220   532.185  5458.75
# 3   668.597   55.0269   437.733   863.881  175.4240   607.365  5691.35
# 4   674.468   48.9362   424.255  1049.790   14.0426   775.745  4041.70
#
#       ZZEF1      ZZZ3
# 0  1894.930  1180.460
# 1  1318.650   406.743
# 2   942.883   509.519
# 3   781.134   700.869
# 4   831.915   881.702
#
# [5 rows x 20514 columns]

# %%
patient_df = patient_df.drop('#Patient Identifier', axis=1)

# %%
patient_df.set_index('Sample Identifier')
# Out:
#                   Overall Survival (Months)  UBE2Q2P2   HMGB1P1  RNU12-2P  \
# Sample Identifier
# TCGA-3C-AAAU-01                 133.0505967   12.9316   52.1503    0.0000
# TCGA-3C-AALI-01                 131.6697899   17.3790   69.7553    1.0875
# TCGA-3C-AALJ-01                 48.45974291    9.2294  154.2970    0.0000
# TCGA-3C-AALK-01                 47.60495775   11.0799  143.8640    0.4137
# TCGA-4H-AAAK-01                 11.44097051   14.4298   84.2128    0.4255
# ...                                     ...       ...       ...       ...
# TCGA-WT-AB44-01                 29.02981885    3.2580   42.2643    4.0725
# TCGA-XX-A899-01                  15.3532564   21.4409  137.7760    2.7559
# TCGA-XX-A89A-01                  16.0436598   27.2744   64.1427    0.4724
# TCGA-Z7-A8R5-01                 108.0645692    7.2933   85.0461    0.5973
# TCGA-Z7-A8R6-01                 107.0454022   24.7795  167.5510    0.3480
#
#                     SSX9P     EZHIP  EFCAB8  SRP14P1  TRIM75P  SPATA31B1P  \
# Sample Identifier
# TCGA-3C-AAAU-01    0.0000    1.7233  0.3447   4.1359   0.6893         0.0
# TCGA-3C-AALI-01    0.5438  144.1000  4.8940   1.6313   0.5438         0.0
# TCGA-3C-AALJ-01    0.0000    0.0000  2.7199   2.7199   0.0000         0.0
# TCGA-3C-AALK-01    0.0000    0.0000  2.0687   4.5511   0.0000         0.0
# TCGA-4H-AAAK-01    0.0000    0.4255  2.9787   2.9787   0.0000         0.0
# ...                   ...       ...     ...      ...      ...         ...
# TCGA-WT-AB44-01    0.0000    0.8145  3.2580   4.0725   0.0000         0.0
# TCGA-XX-A899-01    0.0000    2.7559  1.5748   6.6929   0.0000         0.0
# TCGA-XX-A89A-01    0.0000   17.4776  1.4171   6.6131   0.0000         0.0
# TCGA-Z7-A8R5-01    0.0000    0.0000  0.5973   4.1812   0.0000         0.0
# TCGA-Z7-A8R6-01    0.0000    0.3480  2.7838   4.8717   0.3480         0.0
#
#                    ...    ZWILCH     ZWINT      ZXDA      ZXDB      ZXDC  \
# Sample Identifier  ...
# TCGA-3C-AAAU-01    ...   415.824   931.957  129.5920  1007.780  1658.500
# TCGA-3C-AALI-01    ...  1161.330   965.198   59.8151   448.613  1343.120
# TCGA-3C-AALJ-01    ...   305.422  2531.280   35.3581   533.998   768.812
# TCGA-3C-AALK-01    ...   394.506   668.597   55.0269   437.733   863.881
# TCGA-4H-AAAK-01    ...   405.711   674.468   48.9362   424.255  1049.790
# ...                ...       ...       ...       ...       ...       ...
# TCGA-WT-AB44-01    ...   150.014   180.819   24.4349   243.535   772.959
# TCGA-XX-A899-01    ...   456.047   457.087   70.8661   643.701  1266.540
# TCGA-XX-A89A-01    ...   530.198   694.379   48.6538   341.521  1375.530
# TCGA-Z7-A8R5-01    ...   173.109   258.639   32.2552   248.484   796.225
# TCGA-Z7-A8R6-01    ...   521.169  2435.840   34.4498   389.735   947.890
#
#                      ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3
# Sample Identifier
# TCGA-3C-AAAU-01    258.4940  1208.370   3507.25  1894.930  1180.460
# TCGA-3C-AALI-01    198.4770   603.589   5504.62  1318.650   406.743
# TCGA-3C-AALJ-01    331.8220   532.185   5458.75   942.883   509.519
# TCGA-3C-AALK-01    175.4240   607.365   5691.35   781.134   700.869
# TCGA-4H-AAAK-01     14.0426   775.745   4041.70   831.915   881.702
# ...                     ...       ...       ...       ...       ...
# TCGA-WT-AB44-01     98.5543   315.211  10937.10   800.652   443.087
# TCGA-XX-A899-01     21.2598   688.189   5118.11  1933.860   670.079
# TCGA-XX-A89A-01    164.3840   746.812   5477.56  1437.410   953.708
# TCGA-Z7-A8R5-01     51.9667   505.928   6675.63   754.413   750.829
# TCGA-Z7-A8R6-01    139.5390   573.467   3402.52   564.419   462.114
#
# [1082 rows x 20512 columns]

# %%
patient_df.to_csv('Brca_patients.csv', index= False)

# %%
brc = pd.read_csv('/content/Brca_patients.csv')

# %%
brc = brc.set_index('Sample Identifier')
brc.index.name = None
brc.head(2)
# Out:
#                  Overall Survival (Months)  UBE2Q2P2  HMGB1P1  RNU12-2P  \
# TCGA-3C-AAAU-01                 133.050597   12.9316  52.1503    0.0000
# TCGA-3C-AALI-01                 131.669790   17.3790  69.7553    1.0875
#
#                   SSX9P     EZHIP  EFCAB8  SRP14P1  TRIM75P  SPATA31B1P  ...  \
# TCGA-3C-AAAU-01  0.0000    1.7233  0.3447   4.1359   0.6893         0.0  ...
# TCGA-3C-AALI-01  0.5438  144.1000  4.8940   1.6313   0.5438         0.0  ...
#
#                    ZWILCH    ZWINT      ZXDA      ZXDB     ZXDC   ZYG11A  \
# TCGA-3C-AAAU-01   415.824  931.957  129.5920  1007.780  1658.50  258.494
# TCGA-3C-AALI-01  1161.330  965.198   59.8151   448.613  1343.12  198.477
#
#                    ZYG11B      ZYX    ZZEF1      ZZZ3
# TCGA-3C-AAAU-01  1208.370  3507.25  1894.93  1180.460
# TCGA-3C-AALI-01   603.589  5504.62  1318.65   406.743
#
# [2 rows x 20512 columns]

# %%
import numpy as np

#splitting the created dataset to features and lables
y = np.array(brc['Overall Survival (Months)'], dtype=float)
X = brc.drop('Overall Survival (Months)', axis=1)

# %% [markdown]
# # Handling Pathway Commons Data

# %%
path = "/content/drive/MyDrive/gsoc data/PathwayCommons12.reactome.hgnc.sif.gz"


#specify compression type because the file is compressed
df = pd.read_csv(path, sep="\t", compression="gzip", header=None, names=["Source", "InteractionType", "Target"])

# %%
df = df.drop(columns='InteractionType')

# %%
df.head()
# Out:
#   Source    Target
# 0   A1CF   APOBEC1
# 1   A1CF   APOBEC2
# 2   A1CF  APOBEC3A
# 3   A1CF  APOBEC3B
# 4   A1CF  APOBEC3C

# %%
all_nodes = sorted(list(set(df['Source']) | set(df['Target'])))
len(all_nodes)
# Out:
# 12324

# %%
#getting number of common nodes between pathway commons and newly merged cBio data
used_nodes = sorted(list(set(X.columns) & set(all_nodes)))
len(used_nodes)
# Out:
# 9614

# %%
# Filter rows in the DataFrame where the 'Source' column values are in 'used_nodes'
source_values = df['Source'].values
mask = np.isin(source_values, used_nodes)
df = df.loc[mask]

# Filter rows in the DataFrame where the 'Target' column values are in 'used_nodes'
source_values = df['Target'].values
mask = np.isin(source_values, used_nodes)
df = df.loc[mask]

# Reset the index of the DataFrame after filtering rows
df = df.reset_index(drop=True)

# Display the first two rows of the DataFrame 'X'
X.head(2)
# Out:
#                  UBE2Q2P2  HMGB1P1  RNU12-2P   SSX9P     EZHIP  EFCAB8  \
# TCGA-3C-AAAU-01   12.9316  52.1503    0.0000  0.0000    1.7233  0.3447
# TCGA-3C-AALI-01   17.3790  69.7553    1.0875  0.5438  144.1000  4.8940
#
#                  SRP14P1  TRIM75P  SPATA31B1P  REXO1L6P  ...    ZWILCH  \
# TCGA-3C-AAAU-01   4.1359   0.6893         0.0       0.0  ...   415.824
# TCGA-3C-AALI-01   1.6313   0.5438         0.0       0.0  ...  1161.330
#
#                    ZWINT      ZXDA      ZXDB     ZXDC   ZYG11A    ZYG11B  \
# TCGA-3C-AAAU-01  931.957  129.5920  1007.780  1658.50  258.494  1208.370
# TCGA-3C-AALI-01  965.198   59.8151   448.613  1343.12  198.477   603.589
#
#                      ZYX    ZZEF1      ZZZ3
# TCGA-3C-AAAU-01  3507.25  1894.93  1180.460
# TCGA-3C-AALI-01  5504.62  1318.65   406.743
#
# [2 rows x 20511 columns]

# %%
len(set(df['Source']) | set(df['Target']))
# Out:
# 9288

# %%
# Get the unique values from the 'Source' and 'Target' columns and combine them into a set
columns_to_select = sorted(set(df['Source']).union(set(df['Target'])))

# Select the columns in 'X' that are present in 'columns_to_select'
X = X[columns_to_select]

# Display the first two rows of the updated 'X' DataFrame
X.head(2)
# Out:
#                  A1CF      A2M   A4GNT     AAAS      AACS    AADAT     AAK1  \
# TCGA-3C-AAAU-01   0.0  5798.37  8.6165  649.337  1087.400   5.5145  517.333
# TCGA-3C-AALI-01   0.0  7571.98  0.5438  887.983   836.324  24.4698  848.287
#
#                   AANAT     AARS    AARS2  ...     ZP2      ZP3     ZP4  \
# TCGA-3C-AAAU-01  0.3447  4409.56  689.897  ...  0.0000  411.791  0.0000
# TCGA-3C-AALI-01  2.1751  4570.96  472.501  ...  4.3502  439.222  0.5438
#
#                   ZRANB1    ZRSR2  ZSCAN10     ZW10    ZWILCH    ZWINT  \
# TCGA-3C-AAAU-01  879.225  421.862   2.7573  430.824   415.824  931.957
# TCGA-3C-AALI-01  566.068  349.647   0.0000  340.402  1161.330  965.198
#
#                      ZZZ3
# TCGA-3C-AAAU-01  1180.460
# TCGA-3C-AALI-01   406.743
#
# [2 rows x 9288 columns]

# %% [markdown]
# # Creating Edge Index from Pathway commons

# %%
# !pip install torch-geometric
# Out:
# Collecting torch-geometric
#   Downloading torch_geometric-2.3.1.tar.gz (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.6/661.6 kB 10.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (4.65.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (2.27.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch-geometric) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (pyproject.toml) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910459 sha256=9dac1ca62cb0ae9660d08c65618d1b1ba5a4897d3bb24df33366601dc7c10e65
#   Stored in directory: /root/.cache/pip/wheels/ac/dc/30/e2874821ff308ee67dcd7a66dbde912411e19e35a1addda028
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.3.1

# %%
import torch

# %%
source_nodes = df['Source'].tolist()
target_nodes = df['Target'].tolist()


#Create a dictionary to map each unique node to a unique index
node_to_index = {node: index for index, node in enumerate(X.columns)}

# Map the source and target nodes to their corresponding indices
source_indices = [node_to_index[node] for node in source_nodes]
target_indices = [node_to_index[node] for node in target_nodes]

# %%
# Convert the source and target indices to a PyTorch tensor
edge_index = torch.tensor([source_indices, target_indices], dtype=torch.long)

# %%
X.shape, y.shape
# Out:
# ((1082, 9288), (1082,))

# %%
# Set the fixed indices for splitting using 60:20:20 ratio
train_index = int(0.6 * X.shape[0])
val_index = int(0.6 * X.shape[0]) + int(0.2 * X.shape[0])

# Split the data into train, validation, and test sets
X_train = X[:train_index]
X_val = X[train_index:val_index]
X_test = X[val_index:]
y_train = y[:train_index]
y_val = y[train_index:val_index]
y_test = y[val_index:]

# %%
X_train.shape, X_test.shape, X_val.shape
# Out:
# ((649, 9288), (217, 9288), (216, 9288))

# %%
y_train.shape, y_test.shape, y_val.shape
# Out:
# ((649,), (217,), (216,))

# %% [markdown]
# #Saving the integrated datasets

# %%
# Save the tensor to a file
file_path = 'edge_index.pt'
torch.save(edge_index, file_path)

# %%
import pandas as pd

# Save X_train to a CSV file
X_train.to_csv('X_train.csv')

# Save X_test to a CSV file
X_test.to_csv('X_test.csv')

# Save X_val to a CSV file
X_val.to_csv('X_val.csv')

# Save X_val to a CSV file
np.savetxt('y_val.csv', y_val, delimiter=',')


# Save y_train to a CSV file
np.savetxt('y_train.csv', y_train, delimiter=',')

# Save y_test to a CSV file
np.savetxt('y_test.csv', y_test, delimiter=',')
